# %% [markdown]
# 1-Determine the types of the below-given variables:
#
# Age --> Discrete Variables
#
# Salary --> Continuous Variables
#
# Income --> Continuous Variables
#
# Customer type --> Categorical Variables - Nominal Variables
#
# Stock price --> Continuous Variables

# %% [markdown]
# 2-Using the movie data, we have studied in this lesson. Complete the following tasks:

# %% [markdown]
# -Select a variable from the movie dataset and discuss the variable type of this variable
#
# Seçtiğim değişken   cast_total_facebook_likes, Dtype'ta da yazdığı üzere integer bir değişken.

# %%
import pandas as pd
import numpy as np
movie = pd.read_csv("movie.csv")

movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %% [markdown]
# -Categorize a variable of your choice and assign a name to it
#
# -Count the number of rows for each category

# %%
print(movie. director_facebook_likes)

def likes(director):
    if director >= 10000:
        return 3
    elif (director < 10000) and (director > 5000):
        return 2
    else:
        return 1
    
movie['directorFacebookLikes_grup'] = movie['cast_total_facebook_likes'].apply(likes)
display(movie.head())
movie.groupby("directorFacebookLikes_grup")["director_name"].count()

def likes_situation(director):
    if director >= 10000:
        return "High"
    elif (director < 10000) and (director > 5000):
        return "Medium"
    else:
        return "Low"
    
movie['directorFLSituation_grup'] = movie['cast_total_facebook_likes'].apply(likes_situation)
display(movie.head())
movie.groupby("directorFacebookLikes_grup")["director_name"].count()
# Out:
# 0           0.0
# 1         563.0
# 2           0.0
# 3       22000.0
# 4         131.0
#          ...
# 5038        2.0
# 5039        NaN
# 5040        0.0
# 5041        0.0
# 5042       16.0
# Name: director_facebook_likes, Length: 5043, dtype: float64
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# ...

# %% [markdown]
# 3-Is it possible to convert categorical variable into numerical one? If so, how can you make that?
#
# Categorical variables are variables that are passed as strings. They are the variables we give in quotes. For example, while we have data called male and female, we can give 1 and 0 to make it numerical, thus converting it to binary variables.
#
# Kategorik değişkenler string olarak geçen değişkenlerdir. Tırnak içinde verdiğimiz değişkenlerdir. Örneğin kadın erkek diye datamız var iken bunun numerik olması için 1 ve 0 verebiliriz, bu şekilde binary değişkene çevirmiş oluruz.

# %% [markdown]
# 4-While continuous data is generally preferred over discrete data, please indicate circumstances where discrete is the preferred data type although continuous data is available for the same characteristic.
#
# When there are multiple variables with continuous data, it becomes difficult to map data. The impact on the visualization of such data mappings is enormous and charts / graphs become very complex and confusing. The numbers / labels in this type of chart usually don't make sense. These numbers need to make sense. Therefore, it can be achieved with discrete data to collect numbers in groups or categories and to represent categories as confidential data, thus making the map more structured and presentable.
#
# Sürekli veriye sahip birden fazla değişken olduğunda, verileri haritalamak zorlaşır. Bu tür veri eşlemelerinin görselleştirilmesi üzerindeki etkisi büyüktür ve çizelgeler / grafikler çok karmaşık ve kafa karıştırıcı hale gelir. Bu tür grafiklerdeki sayılar / etiketler genellikle anlam ifade etmez. Bu sayılara anlam verme ihtiyacı vardır. Bu nedenle, sayıların gruplar veya kategoriler halinde toplanması ve kategorilerin gizli veriler olarak temsil edilmesi ve böylece haritanın daha yapılandırılmış ve sunum yapılabilir hale getirilmesi kesikli verilerle sağlanabilir.

# %% [markdown]
# 5- While continuous data is measured and attribute data is counted, there is sometimes confusion if some specific dataset should be considered continuous or attribute. Provide some examples of confusing datasets and your inference.
#
# A certain group of people ages 10,15,20,35,45,60,75,79. These are qualitative data. But it is continuous data in a certain range, for example between the ages of 10-80.
#
# Belirli bir grup insanın yaşları 10,15,20,35,45,60,75,79. Bunlar niteliksel veridir. Fakat belli bir aralıkta örneğin 10-80 arası yaşta sürekli veridir.
