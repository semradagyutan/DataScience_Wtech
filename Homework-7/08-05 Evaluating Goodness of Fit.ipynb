# %% [markdown]
# # Q-1

# %% [markdown]
# Load the weather data from Kaggle
#
# -Like in the previous lesson, build a linear regression model where your target variable is the difference between the apparenttemperature and the temperature. As explanatory variables, use humidity and windspeed. Now, estimate your model using OLS. What are the R-squared and adjusted R-squared values? Do you think they are satisfactory? Why?
#
# -Next, include the interaction of humidity and windspeed to the model above and estimate the model using OLS. Now, what is the R-squared of this model? Does this model improve upon the previous one?
#
# -Add visibility as additional explanatory variable to the first model and estimate it. Did R-squared increase? What about adjusted R-squared? Compare the differences put on the table by the interaction term and the visibility in terms of the improvement in the adjusted R-squared. Which one is more useful?
#
# -Choose the best one from the three models above with respect to their AIC and BIC scores. Validate your choice by discussing your justification with your mentor.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  scipy.stats import zscore
import seaborn as sns
from sklearn import linear_model
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
weather = pd.read_csv("weatherHistory.csv")
weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
#Target Variable
weather["TempatureDif"] = weather["Temperature (C)"] - weather["Apparent Temperature (C)"]

Y = weather["TempatureDif"]

X = weather[["Humidity","Wind Speed (km/h)"]]
X = sm.add_constant(X)

results = sm.OLS(Y,X).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           TempatureDif   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:49   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Sonuçlara göre R-squared ve Adj. R-squared değerleri yüzde 28 değer aldığı görülüyor. Modelin başarısı yani hedef değişkeni açıklama oranı çok düşük. Bu yüzden tatmin edici olmadığı söylenebilir.

# %%
#Target Variable
weather["Hum/Wind"] = weather["Humidity"]*weather["Wind Speed (km/h)"]
Y = weather["TempatureDif"]

X = weather[["Humidity","Wind Speed (km/h)","Hum/Wind"]]
X = sm.add_constant(X)


results = sm.OLS(Y,X).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           TempatureDif   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:49   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Önceki modele göre ilerleme vardır. Çünkü R-squared değerler %34.1 olmuştur. Bu da yeni eklediğimiz feature'ın modelin başarısını arttırdığını söyleyebiliriz.

# %%
Y = weather["TempatureDif"]

X = weather[["Humidity","Wind Speed (km/h)","Visibility (km)"]]
X = sm.add_constant(X)

results = sm.OLS(Y,X).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           TempatureDif   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                 1.401e+04
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:50   Log-Likelihood:            -1.6938e+05
# No. Observations:               96453   AIC:                         3.388e+05
# Df Residuals:                   96449   BIC:                         3.388e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# İlk modele eklediğimiz visibility özelliği sayesinde ilk modele göre r-squared değerleri artmıştır. Fakat açıklama oranları kıyaslaması açısından önceki modele eklediğimiz interaction bu modele göre daha fazla açıklama başarısı elde etmiştir.

# %% [markdown]
# 3 modele göre AIC BIC değerlerinin azalma/artma oranı R-squared değerleri ile ters orantılı. Yani en çok açıklayan modelde AIC BIC değerlerinin en düşük olması beklenir. Bu da görüleceği üzere 2. modelde en düşük, 1 modelde ise en yüksektir. Yani seçilecek model 2. modeldir.

# %% [markdown]
# # Q-2

# %% [markdown]
# Load the houseprices data from Kaggle.
#
# -Run your house prices model again and assess the goodness of fit of your model using F-test, R-squared, adjusted R-squared, AIC and BIC.
#
# -Do you think your model is satisfactory? If so, why?
#
# -In order to improve the goodness of fit of your model, try different model specifications by adding or removing some variables.
#
# -For each model you try, get the goodness of fit metrics and compare your models with each other. Which model is the best and why

# %%
house_train = pd.read_csv("house_train.csv")
house_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house_train.drop(['PoolQC', "Fence", "MiscFeature","FireplaceQu","Alley","LotFrontage"],axis=1,inplace=True)

# %%
house_train["GarageYrBlt"].fillna(house_train["GarageYrBlt"].mode()[0],inplace=True)
house_train["GarageCond"].fillna(house_train["GarageCond"].mode()[0],inplace=True)
house_train["GarageFinish"].fillna(house_train["GarageFinish"].mode()[0],inplace=True)
house_train["GarageArea"].fillna(house_train["GarageArea"].mode()[0],inplace=True)
house_train["GarageQual"].fillna(house_train["GarageQual"].mode()[0],inplace=True)
house_train["GarageCars"].fillna(house_train["GarageCars"].mode()[0],inplace=True)
house_train["GarageType"].fillna(house_train["GarageType"].mode()[0],inplace=True)

house_train.dropna(inplace=True)

# %%
house_train["central_air"]=pd.get_dummies(house_train["CentralAir"], drop_first=True)

# %%
def Saletype(SaleType):
    if SaleType =="WD":
        return 10
    elif SaleType == "CWD":
        return 9
    elif SaleType =="VWD":
        return 8
    elif SaleType =="New":
        return 7
    elif SaleType =="COD":
        return 6
    elif SaleType =="Con":
        return 5
    elif SaleType =="ConLw":
        return 4
    elif SaleType =="ConLI":
        return 3
    elif SaleType =="ConLD":
        return 2
    elif SaleType =="Oth":
        return 1
house_train["SalesType"] = house_train["SaleType"].apply(Saletype)

# %%
def Garagequal(GarageQual):
    if GarageQual=="Ex":
        return 6
    elif GarageQual=="Gd":
        return 5
    elif GarageQual=="TA":
        return 4
    elif GarageQual=="Fa":
        return 3
    elif GarageQual=="Po":
        return 2
    elif GarageQual=="NA":
        return 1


house_train["GarageQuall"] = house_train["GarageQual"].apply(Garagequal)

# %%
def kitchenqual(KitchenQual):
    if KitchenQual=="Ex":
        return 4
    elif KitchenQual=="Gd":
        return 3
    elif KitchenQual=="TA":
        return 2
    elif KitchenQual=="Fa":
        return 1

house_train["Kitchen_Qual"]=house_train["KitchenQual"].apply(kitchenqual)

# %%
Y_ = house_train["SalePrice"]

X_ = house_train[["SalesType","GarageQuall","GarageCars",
                 "central_air","TotRmsAbvGrd","GarageArea","Kitchen_Qual","GrLivArea","LotArea"]]
X_ = sm.add_constant(X_)

results = sm.OLS(Y_,X_).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     406.5
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:50   Log-Likelihood:                -17025.
# No. Observations:                1412   AIC:                         3.407e+04
# Df Residuals:                    1402   BIC:                         3.412e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Değerlere bakıldığı zaman
#
# R-squared = %72.3 Modelin başarısı arttırılmadılır.
# F-Statistic = 0. Modelin anlamlı olduğunu söylemektedir.
#
#
# Modelin başarısı daha iyileştirilebilir olduğu için tam olarak tatmin edici olduğu söylenemez.
# Bu yüzden anlamlı olmayan feature'ları çıkarıp anlamlı olan feature'lar eklenmelidir.

# %%
Y_ = house_train["SalePrice"]

X_ = house_train[["SalesType","GarageQuall","GarageCars",
                 "central_air","TotRmsAbvGrd","Kitchen_Qual","GrLivArea","LotArea"]]
X_ = sm.add_constant(X_)

results = sm.OLS(Y_,X_).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.721
# Method:                 Least Squares   F-statistic:                     456.9
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:50   Log-Likelihood:                -17026.
# No. Observations:                1412   AIC:                         3.407e+04
# Df Residuals:                    1403   BIC:                         3.412e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
Y_ = house_train["SalePrice"]

X_ = house_train[["SalesType","GarageQuall","GarageCars",
                 "central_air","TotRmsAbvGrd","Kitchen_Qual","GrLivArea","LotArea","OverallQual"]]
X_ = sm.add_constant(X_)

results = sm.OLS(Y_,X_).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     519.6
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:50   Log-Likelihood:                -16896.
# No. Observations:                1412   AIC:                         3.381e+04
# Df Residuals:                    1402   BIC:                         3.386e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
Y_ = house_train["SalePrice"]

X_ = house_train[["SalesType","GarageQuall","GarageCars",
                 "central_air","Kitchen_Qual","GrLivArea","LotArea","OverallQual"]]
X_ = sm.add_constant(X_)

results = sm.OLS(Y_,X_).fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     584.6
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):               0.00
# Time:                        11:02:50   Log-Likelihood:                -16896.
# No. Observations:                1412   AIC:                         3.381e+04
# Df Residuals:                    1403   BIC:                         3.386e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# 4 ayrı model kurup denedim.İlk modelde anlamsız olan GarageArea'yı kaldırdım ve daha sonrasında yeni feature olarak OverallQual' ekledim. Böylelikle Başarı oranı %77'ye yükseldi. Fakat tablodaki  değişkenlerin P değerlerini incelediğim zaman TotRmsAbvGrd'ın 0.05 anlam düzeyinden büyük olduğu için bu feature' kaldırdım.
#
# AIC ve BIC değerlerinin son modelde ilk modele göre düştüğü görülmektedir. F istatistik değeri ise 0 olduğu için modelin anlamlı olduğunu söyleyebiliriz.
#
# En iyi model en son kurulan modeldir çünkü R-square değeri en yüksek olan bu modeldir.
